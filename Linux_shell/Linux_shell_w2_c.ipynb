# %% [markdown]
# # Demo for vi Editor
#
# Here are some demo code cells for the most important `vi` commands. These code cells simulate using `vi` in a shell environment, so you can understand the command behavior. Of course, running these commands in an actual terminal is necessary for hands-on practice.
#
# ## Demo 1: Opening a File and Navigating
#
# ### 1.1 Open a file with `vi`
#
# ```bash
# # Open the 'test.bashrc' file in vi
# vi test.bashrc
# ```
#
# ### 1.2 Moving around in `vi`
#
# Once inside `vi`, try the following movements:
#
# ```markdown
# # In Command Mode:
#
# # Move to the start of the line
# 0
#
# # Move to the end of the line
# $
#
# # Move to the beginning of the next word
# w
#
# # Move to the beginning of the previous word
# b
#
# # Move to the first line
# 1G or :0
#
# # Move to the last line
# G or :$
# ```
#
# ---
#
# ## Demo 2: Editing Text in `vi`
#
# ### 2.1 Replacing and Changing Text
#
# ```markdown
# # In Command Mode:
#
# # Replace a single character under the cursor
# r
#
# # Replace text from the cursor position onward until Esc is pressed
# R
#
# # Change a word starting from the current character
# cw
#
# # Change multiple words (e.g., 2 words)
# c2w
# ```
#
# ### 2.2 Deleting Text
#
# ```markdown
# # In Command Mode:
#
# # Delete a single character under the cursor
# x
#
# # Delete a word starting from the current character
# dw
#
# # Delete a full line
# dd
#
# # Delete multiple lines (e.g., 3 lines)
# 3dd
# ```
#
# ---
#
# ## Demo 3: Copying and Pasting Text
#
# ### 3.1 Copy and Paste Operations
#
# ```markdown
# # In Command Mode:
#
# # Copy (yank) the current line
# yy
#
# # Copy the next 2 lines (including the current one)
# 2yy
#
# nyy for y lines
#
# # Paste the yanked text after the current line
# p
#
# # Paste the yanked text before the current line
# P
# ```
#
# ---
#
# ## Demo 4: Searching in `vi`
#
# ### 4.1 Searching for Text
#
# ```markdown
# # In Command Mode:
#
# # Search forward for a string (e.g., 'alias')
# /alias
#
# # Search backward for a string
# ?alias
#
# # Move to the next occurrence of the search term
# n
#
# # Move to the previous occurrence of the search term
# N
# ```
#
# ---
#
# ## Demo 5: Enabling Line Numbers
#
# ### 5.1 Show and Hide Line Numbers
#
# ```markdown
# # In Command Mode:
#
# # Show line numbers
# :se nu
#
# # Hide line numbers
# :se nonu
# ```
#
# ---
#
# ## Demo 6: Saving and Exiting
#
# ### 6.1 Saving and Quitting `vi`
#
# ```markdown
# # In Command Mode:
#
# # Save changes
# :w
#
# # Save and exit
# :wq
#
# # Exit without saving
# :q!
#
# # Save and quit forcefully (if needed)
# :x
# ```
#
# ---
#
# ## Demo 7: Scrolling
#
# ### 7.1 Scrolling through the file
#
# ```markdown
# # In Command Mode:
#
# # Scroll forward one screen
# Ctrl + f
#
# # Scroll backward one screen
# Ctrl + b
#
# # Scroll down half a screen
# Ctrl + d
#
# # Scroll up half a screen
# Ctrl + u
# ```
#
# ---
#
# These demo cells cover the most commonly used `vi` commands, from basic navigation to text editing and searching. Remember, these commands work in `vi` after you've opened a file in command mode.
# ```

# %% [markdown]
# ## Demo 8: Use of `:f` in `vi`
# The `:f` command in `vi` shows the current file name, the line number where your cursor is, and the percentage of the file you have navigated through.
#
# ```bash
# # In `vi`, after opening a file:
# :f
# ```
#
# Example output:
# ```markdown
# "test.bashrc" 20 lines, 346 characters (50%) cursor at line 10
# ```
#
# ---
#
# ## Demo 9: Replacing a Word in `vi`
# ### Explanation:
# - **`r`**: Replaces a **single character** under the cursor.
# - **`cw`**: Changes the word starting at the cursor position. After typing `cw`, replace the old word by typing the new word, then press `Esc`.
#
# ### Example:
# If your cursor is on the word `oldword`:
# 1. Press `cw`, and the word will disappear.
# 2. Type `newword`, then press `Esc`.
#
# ```bash
# # In Command Mode:
# cw
#
# # Now, type the new word:
# newword
#
# # Press Esc to return to Command Mode.
# ```
#
# ---
#
# ## Demo 10: Pressing Enter after `y`
# Pressing `y` copies a **single character**. Pressing `yy` copies the **entire current line**.
#
# ### Demo Example:
# ```bash
# # In Command Mode:
#
# # Copy the current line:
# yy
#
# # Alternatively, press y and then Enter:
# y
# ```
# Result: Both commands (`yy` and `y` + Enter) copy the entire current line.
#
# ---
#
# ## Demo 11: Using `ed` Editor for Search and Replace
#
# The `ed` editor command `:1,2s/line/LINE/` performs a substitution of the word "line" with "LINE" between lines 1 and 2.
#
# ```bash
# # Open the file 'myfile.txt' with `ed`:
# ed myfile.txt
#
# # Replace 'line' with 'LINE' between lines 1 and 2 (first occurence in each line):
# :1,2s/line/LINE/
#
# # Replace 'line' with 'LINE' between lines 1 and 2 (every occurence):
# :1,2s/line/LINE/g
#
# #With g: All matches in each specified line.
# #Without g: Only the first match in each specified line.
#
# # Quit `ed`:
# :q
# ```
#
# ---
#
# ## Demo 12: `:s%/is/IS/` in `vi`
#
# This command searches for the word "is" in the entire file and replaces first occurence in each line with "IS". It works on all lines.
#
# ```bash
# # In Command Mode of `vi`, type the following to replace 'is' with 'IS':
# :s%/is/IS/
# ```
#
# ---
#
# ## Demo 13: Using `scp` to Copy Files from Remote to Local Machine
#
# The `scp` command is used to securely copy files from a remote server to your local machine. Here's an example:
#
# ```bash
# # Copy a file from a remote server to the current directory (.)
# scp user@ipaddress:/path/to/file .
# ```
# ### Explanation:
# - **user**: The username on the remote server.
# - **ipaddress**: The IP address of the remote server.
# - **/path/to/file**: The file's path on the remote server.
# - **`.`**: This refers to the current directory on your local machine.
#
# ---
#
# ## Demo 14: C and tar files:
#
# You can use the `tar` command to extract a `.tar` file after copying it from a remote location (e.g., home or root directory).
#
# ```bash
# # Extract a tar file (untar):
# tar -xvf filename.tar
#
# Explanation:
#
# -x: Extract the file.
# -v: Verbose mode (shows the file names being extracted).
# -f: Specifies the file to extract.
# After running this command, you'll see the extracted directory structure. For example, if project.tar contains a directory named project, it will extract the contents into that directory.
#
# # Navigate to the directory where the file was extracted:
# cd extracted_directory
#
# # Open a C file in that directory:
# vi filename.c
# ```
#
# ---
#
#
# ### Open a C File in `vi`:
# 1. **Regular `vi` open**:
#    ```bash
#    vi filename.c
#    ```
# 2. **Binary mode (`-b`)**:
#    ```bash
#    vi -b filename.c
#    ```
#
# ### Difference:
# - **`vi filename.c`**: Opens the file normally.
# - **`vi -b filename.c`**: Opens the file in **binary mode**. This mode is useful when you're working with **DOS** files or files containing special characters like `^M` (carriage return).
#
# ---
#
# ### What is a DOS File?
# A **DOS file** is a text file formatted for Windows systems, which often ends lines with a **carriage return (CR)** followed by a **line feed (LF)**. The carriage return appears as `^M` at the end of each line when viewed on UNIX/Linux systems.
#
# You can remove these characters using the following command in `vi`:
#
# ```bash
# # In Command Mode of `vi`, type:
# :%s/^M//g
# ```
#
# **Note**: To type `^M` in `vi`, press `Ctrl + v` followed by `Ctrl + m`.
#
# ---
#
# ### Summary of Commands:
# 1. **`vi` navigation**:
#    - Move around with `0`, `$`, `w`, `b`, etc.
# 2. **`r` and `cw`**: Replace characters and words.
# 3. **`yy` vs `y + Enter`**: Copy the current line.
# 4. **`ed` commands**: Search and replace using `:1,2s/line/LINE/`.
# 5. **`scp`**: Securely copy files from remote to local.
# 6. **`tar`**: Extract `.tar` files.
# 7. **DOS Files**: Handle `^M` characters using `:%s/^M//g`.
# ```

# %% [markdown]
# ## Demo 15. Locating Tar Files on Your WSL System
#
# You can search for `.tar` files already present on your system by using the `find` command:
#
# ```bash
# # Search for tar files in your WSL system starting from the home directory
# find ~/ -name "*.tar"
# ```
#
# This command will search for `.tar` files in your home directory (`~/`). If any `.tar` files exist, this command will list them, and you can choose one to work with.
#
# ---
#
# ## Demo 16. Locating C Files on Your WSL System
#
# Similarly, you can search for `.c` files on your system:
#
# ```bash
# # Search for C files in your WSL system starting from the home directory
# find ~/ -name "*.c"
# ```
#
# If you find any C files, you can use them to demonstrate the `vi` commands. If the C file is inside a `.tar` archive, you can extract it as shown in the previous instructions.
#
# ---
#
# ## Demo 17. Working with a Sample Tar File
#
# you can create your own tar file for practice. Here’s how to create a tar file with a C file inside it:
#
# #### 17.1 Create a Directory and C File
#
# ```bash
# # Create a sample directory
# mkdir ~/sample_project
#
# # Navigate to the directory
# cd ~/sample_project
#
# # Create a sample C file
# echo '#include <stdio.h>\nint main() { printf("Hello, World!"); return 0; }' > main.c
# ```
#
# #### 17.2 Create a Tar Archive of the Directory
#
# ```bash
# # Navigate to your home directory
# cd ~
#
# # Create a tar archive containing the C file
# tar -cvf sample_project.tar sample_project/
# ```
#
# Now you have a real `.tar` file (`sample_project.tar`) in your home directory. You can use this file to practice extracting and working with C files.
#
# #### 17.3 Extract the Tar File
#
# ```bash
# # Extract the tar file
# tar -xvf sample_project.tar
# ```
#
# This will extract the `sample_project` directory containing `main.c`.
#
# #### 17.4 Open the C File in `vi`
#
# ```bash
# # Navigate to the extracted directory
# cd sample_project
#
# # Open the C file in vi
# vi main.c
# ```

# %% [markdown]
# ## demo 18 - use one of the C files present on system. I will demonstrate copying, untarring (if applicable), and using `vi` to open and edit the C file.
#
# #### 18.1: Copy the C File
#
# Let's copy the file `pydevd_cython.c` to your home directory or a directory where you can safely experiment.
#
# ```bash
# # Copy the C file to your home directory
# cp /home/kavis/.vscode-server/extensions/ms-python.debugpy-2024.12.0-linux-x64/bundled/libs/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_cython.c ~/pydevd_cython.c
# ```
#
# This command copies the file to your home directory (`~`) and renames it as `pydevd_cython.c`.
#
# ---
#
# #### 18.2: Open the C File in `vi`
#
# Now that the file is copied, open it in `vi` for editing.
#
# ```bash
# # Open the copied C file in vi
# vi ~/pydevd_cython.c
# ```
#
# This opens the C file in `vi`, where you can now navigate and make changes.
#
# ---
#
# #### 18.3: Open the C File in Binary Mode (`-b`)
#
# If you want to open the C file in binary mode to handle special characters (like DOS-style carriage returns), use the following command:
#
# ```bash
# # Open the copied C file in binary mode
# vi -b ~/pydevd_cython.c
# ```
#
# This will open the file in binary mode. If there are any `^M` characters (DOS carriage returns), you can remove them using this command in `vi`:
#
# ```bash
# # Remove ^M characters from a DOS file
# :%s/^M//g
# ```
#
# To type `^M`, press `Ctrl + v` followed by `Ctrl + m`.
#
# ---
#
# #### 18.4: Working with the File in `vi`
#
# You can use the following commands to navigate, edit, and search within the file:
#
#  **Navigation**:
#    - `0`: Move to the beginning of the current line.
#    - `$`: Move to the end of the current line.
#    - `G`: Move to the end of the file.
#    - `gg`: Move to the beginning of the file.
#
#  **Replacing Text**:
#    To replace a word, move the cursor to the beginning of the word and type `cw`, then type the new word and press `Esc`.
#
#    ```bash
#    # Example of replacing a word
#    cw
#    ```
#
#  **Copying and Pasting**:
#    - `yy`: Copy the current line.
#    - `p`: Paste the copied line after the current one.
#
#  **Saving and Exiting**:
#    - `:w`: Save the changes.
#    - `:q`: Quit `vi`.
#    - `:wq`: Save and quit `vi`.
#    - `:q!`: Quit without saving changes.
#
# ---

# %%
# %%bash
# dmesg
# Out:
# [  145.299768] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000f3cbdd86
# [  145.300985] FS-Cache: N-key=[8] '89d8060000000100'
# [  145.392250] FS-Cache: Duplicate cookie detected
# [  145.394035] FS-Cache: O-cookie c=00000b99 [p=00000019 fl=216 nc=0 na=0]
# [  145.394527] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  145.395946] FS-Cache: O-key=[8] 'b5d8060000000100'
# [  145.397086] FS-Cache: N-cookie c=00000b9a [p=00000019 fl=2 nc=0 na=1]
# [  145.398642] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000833f9319
# [  145.399811] FS-Cache: N-key=[8] 'b5d8060000000100'
# [  145.464526] FS-Cache: Duplicate cookie detected
# [  145.465186] FS-Cache: O-cookie c=00000bf1 [p=00000019 fl=216 nc=0 na=0]
# [  145.466101] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  145.466797] FS-Cache: O-key=[8] '44b7060000000100'
# [  145.467293] FS-Cache: N-cookie c=00000bf2 [p=00000019 fl=2 nc=0 na=1]
# [  145.467824] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000a51b27e1
# [  145.468603] FS-Cache: N-key=[8] '44b7060000000100'
# [  145.524246] FS-Cache: Duplicate cookie detected
# [  145.524667] FS-Cache: O-cookie c=00000c41 [p=00000019 fl=216 nc=0 na=0]
# [  145.524898] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  145.525132] FS-Cache: O-key=[8] '9ee5090000000200'
# [  145.525450] FS-Cache: N-cookie c=00000c42 [p=00000019 fl=2 nc=0 na=1]
# [  145.525810] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=0000000081dd43f2
# [  145.526293] FS-Cache: N-key=[8] '9ee5090000000200'
# [  145.542375] FS-Cache: Duplicate cookie detected
# [  145.542794] FS-Cache: O-cookie c=00000c69 [p=00000019 fl=216 nc=0 na=0]
# [  145.543111] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  145.543351] FS-Cache: O-key=[8] '8d72070000000100'
# [  145.543527] FS-Cache: N-cookie c=00000c6a [p=00000019 fl=2 nc=0 na=1]
# [  145.543877] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=000000005e4fd420
# [  145.544344] FS-Cache: N-key=[8] '8d72070000000100'
# [  145.555923] FS-Cache: Duplicate cookie detected
# [  145.556346] FS-Cache: O-cookie c=00000c81 [p=00000019 fl=216 nc=0 na=0]
# [  145.556606] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  145.556825] FS-Cache: O-key=[8] '536a070000000100'
# [  145.557047] FS-Cache: N-cookie c=00000c82 [p=00000019 fl=2 nc=0 na=1]
# [  145.557305] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000c4206ac2
# [  145.557614] FS-Cache: N-key=[8] '536a070000000100'
# [  145.565796] FS-Cache: Duplicate cookie detected
# [  145.566179] FS-Cache: O-cookie c=00000c8f [p=00000019 fl=216 nc=0 na=0]
# [  145.566475] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  145.566739] FS-Cache: O-key=[8] '934e070000000100'
# [  145.567016] FS-Cache: N-cookie c=00000c90 [p=00000019 fl=2 nc=0 na=1]
# [  145.567237] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=0000000096bdb056
# [  145.567531] FS-Cache: N-key=[8] '934e070000000100'
# [  145.580960] FS-Cache: Duplicate cookie detected
# [  145.581368] FS-Cache: O-cookie c=00000cad [p=00000019 fl=216 nc=0 na=0]
# [  145.581654] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  145.581866] FS-Cache: O-key=[8] '71ae110000000200'
# [  145.582375] FS-Cache: N-cookie c=00000cae [p=00000019 fl=2 nc=0 na=1]
# [  145.583153] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=0000000013e10c2b
# [  145.583810] FS-Cache: N-key=[8] '71ae110000000200'
# [  145.596436] FS-Cache: Duplicate cookie detected
# [  145.596945] FS-Cache: O-cookie c=00000cc7 [p=00000019 fl=216 nc=0 na=0]
# [  145.597356] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  145.597609] FS-Cache: O-key=[8] '9de6090000000200'
# [  145.597789] FS-Cache: N-cookie c=00000cc8 [p=00000019 fl=2 nc=0 na=1]
# [  145.598079] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=0000000068eb04d5
# [  145.598425] FS-Cache: N-key=[8] '9de6090000000200'
# [  145.599694] FS-Cache: Duplicate cookie detected
# [  145.600046] FS-Cache: O-cookie c=00000cc9 [p=00000019 fl=216 nc=0 na=0]
# [  145.601850] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  145.602424] FS-Cache: O-key=[8] '70230a0000000300'
# [  145.602851] FS-Cache: N-cookie c=00000cca [p=00000019 fl=2 nc=0 na=1]
# [  145.603217] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000aa4bf7eb
# [  145.603821] FS-Cache: N-key=[8] '70230a0000000300'
# [  145.605227] FS-Cache: Duplicate cookie detected
# [  145.605554] FS-Cache: O-cookie c=00000ccb [p=00000019 fl=216 nc=0 na=0]
# [  145.605861] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  145.606120] FS-Cache: O-key=[8] '526a070000000100'
# [  145.606695] FS-Cache: N-cookie c=00000ccc [p=00000019 fl=2 nc=0 na=1]
# [  145.607124] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=000000003193d3a0
# [  145.607682] FS-Cache: N-key=[8] '526a070000000100'
# [  145.630730] FS-Cache: Duplicate cookie detected
# [  145.631492] FS-Cache: O-cookie c=00000d02 [p=00000019 fl=216 nc=0 na=0]
# [  145.631817] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  145.632231] FS-Cache: O-key=[8] '6ec2070000000500'
# [  145.632641] FS-Cache: N-cookie c=00000d01 [p=00000019 fl=2 nc=0 na=1]
# [  145.633031] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000e2fc5507
# [  145.633949] FS-Cache: N-key=[8] '6ec2070000000500'
# [  145.635571] FS-Cache: Duplicate cookie detected
# [  145.635896] FS-Cache: O-cookie c=00000d05 [p=00000019 fl=216 nc=0 na=0]
# [  145.636128] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  145.636492] FS-Cache: O-key=[8] '8086070000000100'
# [  145.636831] FS-Cache: N-cookie c=00000d06 [p=00000019 fl=2 nc=0 na=1]
# [  145.637137] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=0000000073a1c04c
# [  145.637600] FS-Cache: N-key=[8] '8086070000000100'
# [  145.704898] FS-Cache: Duplicate cookie detected
# [  145.705463] FS-Cache: O-cookie c=00000db3 [p=00000019 fl=216 nc=0 na=0]
# [  145.705869] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  145.706219] FS-Cache: O-key=[8] '1877070000000100'
# [  145.706514] FS-Cache: N-cookie c=00000db4 [p=00000019 fl=2 nc=0 na=1]
# [  145.706881] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000f1c89ec7
# [  145.707293] FS-Cache: N-key=[8] '1877070000000100'
# [  145.708322] FS-Cache: Duplicate cookie detected
# [  145.708668] FS-Cache: O-cookie c=00000db5 [p=00000019 fl=216 nc=0 na=0]
# [  145.708948] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  145.709162] FS-Cache: O-key=[8] '252c0a0000000100'
# [  145.709654] FS-Cache: N-cookie c=00000db6 [p=00000019 fl=2 nc=0 na=1]
# [  145.710130] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=000000003269b126
# [  145.710526] FS-Cache: N-key=[8] '252c0a0000000100'
# [  145.714016] FS-Cache: Duplicate cookie detected
# [  145.714353] FS-Cache: O-cookie c=00000dbb [p=00000019 fl=216 nc=0 na=0]
# [  145.714586] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  145.714918] FS-Cache: O-key=[8] '0c70070000000100'
# [  145.715108] FS-Cache: N-cookie c=00000dbc [p=00000019 fl=2 nc=0 na=1]
# [  145.715487] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000ad11d69e
# [  145.715865] FS-Cache: N-key=[8] '0c70070000000100'
# [  145.718794] FS-Cache: Duplicate cookie detected
# [  145.719287] FS-Cache: O-cookie c=00000dc1 [p=00000019 fl=216 nc=0 na=0]
# [  145.719690] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  145.719950] FS-Cache: O-key=[8] '065c0a0000000200'
# [  145.720164] FS-Cache: N-cookie c=00000dc2 [p=00000019 fl=2 nc=0 na=1]
# [  145.720424] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=0000000068eb04d5
# [  145.720774] FS-Cache: N-key=[8] '065c0a0000000200'
# [  145.723576] FS-Cache: Duplicate cookie detected
# [  145.723878] FS-Cache: O-cookie c=00000dc7 [p=00000019 fl=216 nc=0 na=0]
# [  145.724127] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  145.724551] FS-Cache: O-key=[8] 'ddaf110000000200'
# [  145.724877] FS-Cache: N-cookie c=00000dc8 [p=00000019 fl=2 nc=0 na=1]
# [  145.725279] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000bb1c68ed
# [  145.725760] FS-Cache: N-key=[8] 'ddaf110000000200'
# [  145.729647] FS-Cache: Duplicate cookie detected
# [  145.730053] FS-Cache: O-cookie c=00000dcf [p=00000019 fl=216 nc=0 na=0]
# [  145.730307] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  145.730604] FS-Cache: O-key=[8] '3f45070000000100'
# [  145.730926] FS-Cache: N-cookie c=00000dd0 [p=00000019 fl=2 nc=0 na=1]
# [  145.731314] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=0000000042447109
# [  145.731790] FS-Cache: N-key=[8] '3f45070000000100'
# [  145.757756] FS-Cache: Duplicate cookie detected
# [  145.758272] FS-Cache: O-cookie c=00000e0b [p=00000019 fl=216 nc=0 na=0]
# [  145.758670] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  145.759055] FS-Cache: O-key=[8] 'e34f070000000100'
# [  145.759369] FS-Cache: N-cookie c=00000e0c [p=00000019 fl=2 nc=0 na=1]
# [  145.759747] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000ba389556
# [  145.760153] FS-Cache: N-key=[8] 'e34f070000000100'
# [  145.767036] FS-Cache: Duplicate cookie detected
# [  145.767395] FS-Cache: O-cookie c=00000e1d [p=00000019 fl=216 nc=0 na=0]
# [  145.767671] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  145.767958] FS-Cache: O-key=[8] 'b02c0a0000000100'
# [  145.768163] FS-Cache: N-cookie c=00000e1e [p=00000019 fl=2 nc=0 na=1]
# [  145.768450] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=000000002db37a4e
# [  145.768808] FS-Cache: N-key=[8] 'b02c0a0000000100'
# [  145.773565] FS-Cache: Duplicate cookie detected
# [  145.773931] FS-Cache: O-cookie c=00000e23 [p=00000019 fl=216 nc=0 na=0]
# [  145.774199] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  145.774515] FS-Cache: O-key=[8] '964b070000000100'
# [  145.774738] FS-Cache: N-cookie c=00000e24 [p=00000019 fl=2 nc=0 na=1]
# [  145.775007] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000f078b3f9
# [  145.775327] FS-Cache: N-key=[8] '964b070000000100'
# [  145.777825] FS-Cache: Duplicate cookie detected
# [  145.778169] FS-Cache: O-cookie c=00000e29 [p=00000019 fl=216 nc=0 na=0]
# [  145.778428] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  145.778716] FS-Cache: O-key=[8] 'e82a080000000200'
# [  145.778995] FS-Cache: N-cookie c=00000e2a [p=00000019 fl=2 nc=0 na=1]
# [  145.779254] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000a6cfcf32
# [  145.779549] FS-Cache: N-key=[8] 'e82a080000000200'
# [  145.780595] FS-Cache: Duplicate cookie detected
# [  145.780949] FS-Cache: O-cookie c=00000e2b [p=00000019 fl=216 nc=0 na=0]
# [  145.781361] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  145.781691] FS-Cache: O-key=[8] 'ec2a080000000200'
# [  145.782064] FS-Cache: N-cookie c=00000e2c [p=00000019 fl=2 nc=0 na=1]
# [  145.782527] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000ed1fef66
# [  145.783002] FS-Cache: N-key=[8] 'ec2a080000000200'
# [  145.790024] FS-Cache: Duplicate cookie detected
# [  145.790287] FS-Cache: O-cookie c=00000e37 [p=00000019 fl=216 nc=0 na=0]
# [  145.790489] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  145.790797] FS-Cache: O-key=[8] 'b24d070000000100'
# [  145.791004] FS-Cache: N-cookie c=00000e38 [p=00000019 fl=2 nc=0 na=1]
# [  145.791374] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=0000000093248978
# [  145.791849] FS-Cache: N-key=[8] 'b24d070000000100'
# [  145.794442] FS-Cache: Duplicate cookie detected
# [  145.794998] FS-Cache: O-cookie c=00000e3d [p=00000019 fl=216 nc=0 na=0]
# [  145.795415] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  145.795841] FS-Cache: O-key=[8] '5149070000000100'
# [  145.796169] FS-Cache: N-cookie c=00000e3e [p=00000019 fl=2 nc=0 na=1]
# [  145.796552] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=0000000001be6e13
# [  145.796967] FS-Cache: N-key=[8] '5149070000000100'
# [  145.798261] FS-Cache: Duplicate cookie detected
# [  145.798582] FS-Cache: O-cookie c=00000e3f [p=00000019 fl=216 nc=0 na=0]
# [  145.798966] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  145.799368] FS-Cache: O-key=[8] '6e9f070000000500'
# [  145.799674] FS-Cache: N-cookie c=00000e40 [p=00000019 fl=2 nc=0 na=1]
# [  145.800028] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=0000000050630ac1
# [  145.800543] FS-Cache: N-key=[8] '6e9f070000000500'
# [  145.806657] FS-Cache: Duplicate cookie detected
# [  145.807209] FS-Cache: O-cookie c=00000e4d [p=00000019 fl=216 nc=0 na=0]
# [  145.807710] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  145.808135] FS-Cache: O-key=[8] 'adf3090000000200'
# [  145.808463] FS-Cache: N-cookie c=00000e4e [p=00000019 fl=2 nc=0 na=1]
# [  145.808853] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=000000009bb45358
# [  145.809326] FS-Cache: N-key=[8] 'adf3090000000200'
# [  145.830431] FS-Cache: Duplicate cookie detected
# [  145.831074] FS-Cache: O-cookie c=00000e85 [p=00000019 fl=216 nc=0 na=0]
# [  145.831372] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  145.831852] FS-Cache: O-key=[8] 'd6f0090000000200'
# [  145.832162] FS-Cache: N-cookie c=00000e86 [p=00000019 fl=2 nc=0 na=1]
# [  145.832481] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000a51b27e1
# [  145.832827] FS-Cache: N-key=[8] 'd6f0090000000200'
# [  145.836669] FS-Cache: Duplicate cookie detected
# [  145.837329] FS-Cache: O-cookie c=00000e8d [p=00000019 fl=216 nc=0 na=0]
# [  145.837890] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  145.838184] FS-Cache: O-key=[8] '657f070000000100'
# [  145.838393] FS-Cache: N-cookie c=00000e8e [p=00000019 fl=2 nc=0 na=1]
# [  145.838657] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000ec804832
# [  145.839145] FS-Cache: N-key=[8] '657f070000000100'
# [  145.852878] FS-Cache: Duplicate cookie detected
# [  145.853272] FS-Cache: O-cookie c=00000eab [p=00000019 fl=216 nc=0 na=0]
# [  145.853578] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  145.854271] FS-Cache: O-key=[8] '3c6a070000000100'
# [  145.854740] FS-Cache: N-cookie c=00000eac [p=00000019 fl=2 nc=0 na=1]
# [  145.855732] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000ea24a194
# [  145.856288] FS-Cache: N-key=[8] '3c6a070000000100'
# [  145.860359] FS-Cache: Duplicate cookie detected
# [  145.860793] FS-Cache: O-cookie c=00000eb3 [p=00000019 fl=216 nc=0 na=0]
# [  145.862031] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  145.863072] FS-Cache: O-key=[8] 'a7bd060000000200'
# [  145.863320] FS-Cache: N-cookie c=00000eb4 [p=00000019 fl=2 nc=0 na=1]
# [  145.863709] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000150a7444
# [  145.864187] FS-Cache: N-key=[8] 'a7bd060000000200'
# [  145.865635] FS-Cache: Duplicate cookie detected
# [  145.866001] FS-Cache: O-cookie c=00000eb5 [p=00000019 fl=216 nc=0 na=0]
# [  145.866410] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  145.866820] FS-Cache: O-key=[8] '10320a0000000200'
# [  145.867157] FS-Cache: N-cookie c=00000eb6 [p=00000019 fl=2 nc=0 na=1]
# [  145.867709] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=000000008ee1052e
# [  145.868709] FS-Cache: N-key=[8] '10320a0000000200'
# [  145.879098] FS-Cache: Duplicate cookie detected
# [  145.879542] FS-Cache: O-cookie c=00000ec9 [p=00000019 fl=216 nc=0 na=0]
# [  145.880004] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  145.880443] FS-Cache: O-key=[8] 'b7d1090000000200'
# [  145.880781] FS-Cache: N-cookie c=00000eca [p=00000019 fl=2 nc=0 na=1]
# [  145.881210] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000b7d85dea
# [  145.881729] FS-Cache: N-key=[8] 'b7d1090000000200'
# [  145.909111] FS-Cache: Duplicate cookie detected
# [  145.909700] FS-Cache: O-cookie c=00000f09 [p=00000019 fl=216 nc=0 na=0]
# [  145.910524] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  145.911690] FS-Cache: O-key=[8] '3cf4090000000200'
# [  145.912603] FS-Cache: N-cookie c=00000f0a [p=00000019 fl=2 nc=0 na=1]
# [  145.913094] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000997b79b4
# [  145.913527] FS-Cache: N-key=[8] '3cf4090000000200'
# [  145.916617] FS-Cache: Duplicate cookie detected
# [  145.917096] FS-Cache: O-cookie c=00000f0f [p=00000019 fl=216 nc=0 na=0]
# [  145.917506] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  145.918358] FS-Cache: O-key=[8] '2d70070000000100'
# [  145.918731] FS-Cache: N-cookie c=00000f10 [p=00000019 fl=2 nc=0 na=1]
# [  145.919448] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=0000000031004e0b
# [  145.920087] FS-Cache: N-key=[8] '2d70070000000100'
# [  145.968632] FS-Cache: Duplicate cookie detected
# [  145.969685] FS-Cache: O-cookie c=00000f5f [p=00000019 fl=216 nc=0 na=0]
# [  145.970116] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  145.970447] FS-Cache: O-key=[8] 'b5560a0000000400'
# [  145.970810] FS-Cache: N-cookie c=00000f60 [p=00000019 fl=2 nc=0 na=1]
# [  145.971272] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=000000007fb45d4a
# [  145.971756] FS-Cache: N-key=[8] 'b5560a0000000400'
# [  145.975083] FS-Cache: Duplicate cookie detected
# [  145.975530] FS-Cache: O-cookie c=00000f65 [p=00000019 fl=216 nc=0 na=0]
# [  145.976086] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  145.976401] FS-Cache: O-key=[8] '664f070000000100'
# [  145.976791] FS-Cache: N-cookie c=00000f66 [p=00000019 fl=2 nc=0 na=1]
# [  145.977341] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000041f5d50
# [  145.977858] FS-Cache: N-key=[8] '664f070000000100'
# [  146.023528] FS-Cache: Duplicate cookie detected
# [  146.023970] FS-Cache: O-cookie c=00000fab [p=00000019 fl=216 nc=0 na=0]
# [  146.025139] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  146.025577] FS-Cache: O-key=[8] '60a7110000000200'
# [  146.026019] FS-Cache: N-cookie c=00000fac [p=00000019 fl=2 nc=0 na=1]
# [  146.026530] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=000000000a1495bb
# [  146.027157] FS-Cache: N-key=[8] '60a7110000000200'
# [  146.038390] FS-Cache: Duplicate cookie detected
# [  146.039844] FS-Cache: O-cookie c=00000fbd [p=00000019 fl=216 nc=0 na=0]
# [  146.041128] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  146.042123] FS-Cache: O-key=[8] '9480070000000100'
# [  146.043593] FS-Cache: N-cookie c=00000fbe [p=00000019 fl=2 nc=0 na=1]
# [  146.045141] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=0000000040c7c911
# [  146.046764] FS-Cache: N-key=[8] '9480070000000100'
# [  146.056719] FS-Cache: Duplicate cookie detected
# [  146.058102] FS-Cache: O-cookie c=00000fc5 [p=00000019 fl=216 nc=0 na=0]
# [  146.060056] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  146.061401] FS-Cache: O-key=[8] 'af84070000000100'
# [  146.063063] FS-Cache: N-cookie c=00000fc6 [p=00000019 fl=2 nc=0 na=1]
# [  146.065295] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000d834a7c0
# [  146.067760] FS-Cache: N-key=[8] 'af84070000000100'
# [  146.092865] FS-Cache: Duplicate cookie detected
# [  146.093772] FS-Cache: O-cookie c=00000fd9 [p=00000019 fl=216 nc=0 na=0]
# [  146.094990] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  146.095912] FS-Cache: O-key=[8] '6529080000000200'
# [  146.097202] FS-Cache: N-cookie c=00000fda [p=00000019 fl=2 nc=0 na=1]
# [  146.098540] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=000000009978e160
# [  146.100207] FS-Cache: N-key=[8] '6529080000000200'
# [  146.124099] FS-Cache: Duplicate cookie detected
# [  146.125782] FS-Cache: O-cookie c=00000feb [p=00000019 fl=216 nc=0 na=0]
# [  146.127812] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  146.129533] FS-Cache: O-key=[8] '8129080000000200'
# [  146.130727] FS-Cache: N-cookie c=00000fec [p=00000019 fl=2 nc=0 na=1]
# [  146.132191] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000e7040a87
# [  146.133951] FS-Cache: N-key=[8] '8129080000000200'
# [  146.214937] FS-Cache: Duplicate cookie detected
# [  146.216439] FS-Cache: O-cookie c=00001033 [p=00000019 fl=216 nc=0 na=0]
# [  146.218530] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  146.220663] FS-Cache: O-key=[8] '55db000000001200'
# [  146.221931] FS-Cache: N-cookie c=00001034 [p=00000019 fl=2 nc=0 na=1]
# [  146.224139] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000e002fbdb
# [  146.225807] FS-Cache: N-key=[8] '55db000000001200'
# [  146.292203] FS-Cache: Duplicate cookie detected
# [  146.293480] FS-Cache: O-cookie c=00001071 [p=00000019 fl=216 nc=0 na=0]
# [  146.294569] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  146.295594] FS-Cache: O-key=[8] '840e070000000100'
# [  146.296464] FS-Cache: N-cookie c=00001072 [p=00000019 fl=2 nc=0 na=1]
# [  146.296994] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=000000007f97dd49
# [  146.297842] FS-Cache: N-key=[8] '840e070000000100'
# [  146.306451] FS-Cache: Duplicate cookie detected
# [  146.308105] FS-Cache: O-cookie c=00001077 [p=00000019 fl=216 nc=0 na=0]
# [  146.309513] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  146.310636] FS-Cache: O-key=[8] '68cc090000000300'
# [  146.311761] FS-Cache: N-cookie c=00001078 [p=00000019 fl=2 nc=0 na=1]
# [  146.313451] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=000000006bd9e831
# [  146.315133] FS-Cache: N-key=[8] '68cc090000000300'
# [  146.449776] FS-Cache: Duplicate cookie detected
# [  146.450929] FS-Cache: O-cookie c=000010fd [p=00000019 fl=216 nc=0 na=0]
# [  146.452224] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  146.453277] FS-Cache: O-key=[8] 'cbaf090000000600'
# [  146.454614] FS-Cache: N-cookie c=000010fe [p=00000019 fl=2 nc=0 na=1]
# [  146.455762] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=000000001e39bb71
# [  146.457366] FS-Cache: N-key=[8] 'cbaf090000000600'
# [  146.488028] FS-Cache: Duplicate cookie detected
# [  146.489424] FS-Cache: O-cookie c=00001119 [p=00000019 fl=216 nc=0 na=0]
# [  146.491171] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  146.492665] FS-Cache: O-key=[8] '9f720a0000000100'
# [  146.493676] FS-Cache: N-cookie c=0000111a [p=00000019 fl=2 nc=0 na=1]
# [  146.494531] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=0000000096bdb056
# [  146.495986] FS-Cache: N-key=[8] '9f720a0000000100'
# [  146.559101] FS-Cache: Duplicate cookie detected
# [  146.560476] FS-Cache: O-cookie c=0000114f [p=00000019 fl=216 nc=0 na=0]
# [  146.562683] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  146.564315] FS-Cache: O-key=[8] '374e070000000100'
# [  146.565171] FS-Cache: N-cookie c=00001150 [p=00000019 fl=2 nc=0 na=1]
# [  146.566442] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=000000000fd74094
# [  146.567768] FS-Cache: N-key=[8] '374e070000000100'
# [  146.743658] FS-Cache: Duplicate cookie detected
# [  146.745641] FS-Cache: O-cookie c=000011ff [p=00000019 fl=216 nc=0 na=0]
# [  146.747649] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  146.749728] FS-Cache: O-key=[8] 'ddbd110000000200'
# [  146.751424] FS-Cache: N-cookie c=00001200 [p=00000019 fl=2 nc=0 na=1]
# [  146.753393] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=0000000016ad911c
# [  146.755464] FS-Cache: N-key=[8] 'ddbd110000000200'
# [  146.765006] FS-Cache: Duplicate cookie detected
# [  146.766761] FS-Cache: O-cookie c=00001207 [p=00000019 fl=216 nc=0 na=0]
# [  146.768881] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  146.770922] FS-Cache: O-key=[8] '1f4d070000000100'
# [  146.772098] FS-Cache: N-cookie c=00001208 [p=00000019 fl=2 nc=0 na=1]
# [  146.773405] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=000000000a777d27
# [  146.775605] FS-Cache: N-key=[8] '1f4d070000000100'
# [  146.873912] FS-Cache: Duplicate cookie detected
# [  146.874416] FS-Cache: O-cookie c=000012a3 [p=00000019 fl=216 nc=0 na=0]
# [  146.874796] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  146.875053] FS-Cache: O-key=[8] 'd487070000000100'
# [  146.875261] FS-Cache: N-cookie c=000012a4 [p=00000019 fl=2 nc=0 na=1]
# [  146.875581] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000ad11d69e
# [  146.876122] FS-Cache: N-key=[8] 'd487070000000100'
# [  146.970798] FS-Cache: Duplicate cookie detected
# [  146.972240] FS-Cache: O-cookie c=000012f5 [p=00000019 fl=216 nc=0 na=0]
# [  146.973836] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  146.975260] FS-Cache: O-key=[8] '3db4090000000300'
# [  146.976030] FS-Cache: N-cookie c=000012f6 [p=00000019 fl=2 nc=0 na=1]
# [  146.977119] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000daa83b2d
# [  146.978803] FS-Cache: N-key=[8] '3db4090000000300'
# [  147.042147] FS-Cache: Duplicate cookie detected
# [  147.043493] FS-Cache: O-cookie c=0000133f [p=00000019 fl=216 nc=0 na=0]
# [  147.045220] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  147.046878] FS-Cache: O-key=[8] '7eb8060000000100'
# [  147.048204] FS-Cache: N-cookie c=00001340 [p=00000019 fl=2 nc=0 na=1]
# [  147.049646] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=000000008a257b93
# [  147.051298] FS-Cache: N-key=[8] '7eb8060000000100'
# [  147.167660] FS-Cache: Duplicate cookie detected
# [  147.169188] FS-Cache: O-cookie c=000013b5 [p=00000019 fl=216 nc=0 na=0]
# [  147.170304] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  147.171198] FS-Cache: O-key=[8] 'b9b8060000000100'
# [  147.172095] FS-Cache: N-cookie c=000013b6 [p=00000019 fl=2 nc=0 na=1]
# [  147.173508] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000f8672a4e
# [  147.174661] FS-Cache: N-key=[8] 'b9b8060000000100'
# [  147.498214] FS-Cache: Duplicate cookie detected
# [  147.499812] FS-Cache: O-cookie c=000014f7 [p=00000019 fl=216 nc=0 na=0]
# [  147.501249] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  147.503024] FS-Cache: O-key=[8] '5749070000000100'
# [  147.504430] FS-Cache: N-cookie c=000014f8 [p=00000019 fl=2 nc=0 na=1]
# [  147.505889] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000bca73455
# [  147.506844] FS-Cache: N-key=[8] '5749070000000100'
# [  147.600719] FS-Cache: Duplicate cookie detected
# [  147.601914] FS-Cache: O-cookie c=00001547 [p=00000019 fl=216 nc=0 na=0]
# [  147.602936] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  147.604598] FS-Cache: O-key=[8] 'cfe5090000000200'
# [  147.606069] FS-Cache: N-cookie c=00001548 [p=00000019 fl=2 nc=0 na=1]
# [  147.607645] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=0000000036c69e9f
# [  147.609320] FS-Cache: N-key=[8] 'cfe5090000000200'
# [  147.746684] FS-Cache: Duplicate cookie detected
# [  147.748321] FS-Cache: O-cookie c=000015c3 [p=00000019 fl=216 nc=0 na=0]
# [  147.750270] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  147.752102] FS-Cache: O-key=[8] 'c66f070000000100'
# [  147.753696] FS-Cache: N-cookie c=000015c4 [p=00000019 fl=2 nc=0 na=1]
# [  147.755762] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=0000000069579b32
# [  147.757643] FS-Cache: N-key=[8] 'c66f070000000100'
# [  147.837903] FS-Cache: Duplicate cookie detected
# [  147.839767] FS-Cache: O-cookie c=00001611 [p=00000019 fl=216 nc=0 na=0]
# [  147.841415] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  147.843422] FS-Cache: O-key=[8] '6dd0090000000600'
# [  147.844467] FS-Cache: N-cookie c=00001612 [p=00000019 fl=2 nc=0 na=1]
# [  147.846358] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000ff73fd45
# [  147.848966] FS-Cache: N-key=[8] '6dd0090000000600'
# [  147.872720] FS-Cache: Duplicate cookie detected
# [  147.875363] FS-Cache: O-cookie c=00001629 [p=00000019 fl=216 nc=0 na=0]
# [  147.877504] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  147.878186] FS-Cache: O-key=[8] 'd2e4090000000200'
# [  147.878673] FS-Cache: N-cookie c=0000162a [p=00000019 fl=2 nc=0 na=1]
# [  147.879835] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=000000000a777d27
# [  147.881204] FS-Cache: N-key=[8] 'd2e4090000000200'
# [  147.933508] FS-Cache: Duplicate cookie detected
# [  147.934643] FS-Cache: O-cookie c=00001661 [p=00000019 fl=216 nc=0 na=0]
# [  147.936377] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  147.937844] FS-Cache: O-key=[8] '7bf1040000000400'
# [  147.939476] FS-Cache: N-cookie c=00001662 [p=00000019 fl=2 nc=0 na=1]
# [  147.941087] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000bca73455
# [  147.942858] FS-Cache: N-key=[8] '7bf1040000000400'
# [  147.950313] FS-Cache: Duplicate cookie detected
# [  147.951970] FS-Cache: O-cookie c=00001668 [p=00000019 fl=216 nc=0 na=0]
# [  147.953453] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  147.954992] FS-Cache: O-key=[8] '7ef1040000000400'
# [  147.956552] FS-Cache: N-cookie c=00001669 [p=00000019 fl=2 nc=0 na=1]
# [  147.957816] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=000000004a8f70c0
# [  147.959516] FS-Cache: N-key=[8] '7ef1040000000400'
# [  148.036142] FS-Cache: Duplicate cookie detected
# [  148.037672] FS-Cache: O-cookie c=000016b9 [p=00000019 fl=216 nc=0 na=0]
# [  148.039170] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  148.041041] FS-Cache: O-key=[8] '90b3070000000f00'
# [  148.042238] FS-Cache: N-cookie c=000016ba [p=00000019 fl=2 nc=0 na=1]
# [  148.043880] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000e5fd1af2
# [  148.045733] FS-Cache: N-key=[8] '90b3070000000f00'
# [  148.055617] FS-Cache: Duplicate cookie detected
# [  148.056806] FS-Cache: O-cookie c=000016c3 [p=00000019 fl=216 nc=0 na=0]
# [  148.058353] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  148.060816] FS-Cache: O-key=[8] '82f1040000000400'
# [  148.062209] FS-Cache: N-cookie c=000016c4 [p=00000019 fl=2 nc=0 na=1]
# [  148.063491] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000c77add08
# [  148.065955] FS-Cache: N-key=[8] '82f1040000000400'
# [  148.069412] FS-Cache: Duplicate cookie detected
# [  148.070587] FS-Cache: O-cookie c=000016c5 [p=00000019 fl=216 nc=0 na=0]
# [  148.072595] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  148.074265] FS-Cache: O-key=[8] '83f1040000000400'
# [  148.075122] FS-Cache: N-cookie c=000016c6 [p=00000019 fl=2 nc=0 na=1]
# [  148.076767] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000052c7b58
# [  148.078928] FS-Cache: N-key=[8] '83f1040000000400'
# [  148.199146] FS-Cache: Duplicate cookie detected
# [  148.200549] FS-Cache: O-cookie c=00001731 [p=00000019 fl=216 nc=0 na=0]
# [  148.201609] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  148.203142] FS-Cache: O-key=[8] '81b9060000000100'
# [  148.204616] FS-Cache: N-cookie c=00001732 [p=00000019 fl=2 nc=0 na=1]
# [  148.205759] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000a68beb4f
# [  148.207590] FS-Cache: N-key=[8] '81b9060000000100'
# [  148.245360] FS-Cache: Duplicate cookie detected
# [  148.247381] FS-Cache: O-cookie c=00001751 [p=00000019 fl=216 nc=0 na=0]
# [  148.249094] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  148.250440] FS-Cache: O-key=[8] '724b0a0000000200'
# [  148.251639] FS-Cache: N-cookie c=00001752 [p=00000019 fl=2 nc=0 na=1]
# [  148.253277] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=000000001ec895c3
# [  148.255583] FS-Cache: N-key=[8] '724b0a0000000200'
# [  148.378735] FS-Cache: Duplicate cookie detected
# [  148.380237] FS-Cache: O-cookie c=000017b7 [p=00000019 fl=216 nc=0 na=0]
# [  148.382973] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  148.384773] FS-Cache: O-key=[8] '9c52070000000100'
# [  148.385687] FS-Cache: N-cookie c=000017b8 [p=00000019 fl=2 nc=0 na=1]
# [  148.387757] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=000000009e70d44b
# [  148.389344] FS-Cache: N-key=[8] '9c52070000000100'
# [  148.437370] FS-Cache: Duplicate cookie detected
# [  148.438404] FS-Cache: O-cookie c=000017e3 [p=00000019 fl=216 nc=0 na=0]
# [  148.440588] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  148.442132] FS-Cache: O-key=[8] 'a0580a0000000100'
# [  148.443393] FS-Cache: N-cookie c=000017e4 [p=00000019 fl=2 nc=0 na=1]
# [  148.445231] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=0000000061409b5d
# [  148.447439] FS-Cache: N-key=[8] 'a0580a0000000100'
# [  148.502591] FS-Cache: Duplicate cookie detected
# [  148.504155] FS-Cache: O-cookie c=00001815 [p=00000019 fl=216 nc=0 na=0]
# [  148.506381] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  148.507987] FS-Cache: O-key=[8] 'a6b9060000000100'
# [  148.509020] FS-Cache: N-cookie c=00001816 [p=00000019 fl=2 nc=0 na=1]
# [  148.510208] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000f30512b8
# [  148.511764] FS-Cache: N-key=[8] 'a6b9060000000100'
# [  148.591038] FS-Cache: Duplicate cookie detected
# [  148.592969] FS-Cache: O-cookie c=00001859 [p=00000019 fl=216 nc=0 na=0]
# [  148.594827] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  148.595980] FS-Cache: O-key=[8] '1c4d070000000100'
# [  148.597131] FS-Cache: N-cookie c=0000185a [p=00000019 fl=2 nc=0 na=1]
# [  148.598859] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=000000004fc56bb2
# [  148.600174] FS-Cache: N-key=[8] '1c4d070000000100'
# [  148.698482] FS-Cache: Duplicate cookie detected
# [  148.699966] FS-Cache: O-cookie c=000018b7 [p=00000019 fl=216 nc=0 na=0]
# [  148.701106] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  148.702615] FS-Cache: O-key=[8] '7f240a0000000100'
# [  148.703772] FS-Cache: N-cookie c=000018b8 [p=00000019 fl=2 nc=0 na=1]
# [  148.704704] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=0000000060a797f1
# [  148.706558] FS-Cache: N-key=[8] '7f240a0000000100'
# [  148.863857] FS-Cache: Duplicate cookie detected
# [  148.866096] FS-Cache: O-cookie c=0000194d [p=00000019 fl=216 nc=0 na=0]
# [  148.867460] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  148.869591] FS-Cache: O-key=[8] 'a443070000000100'
# [  148.871472] FS-Cache: N-cookie c=0000194e [p=00000019 fl=2 nc=0 na=1]
# [  148.874023] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=0000000093248978
# [  148.875874] FS-Cache: N-key=[8] 'a443070000000100'
# [  148.935374] FS-Cache: Duplicate cookie detected
# [  148.936579] FS-Cache: O-cookie c=00001981 [p=00000019 fl=216 nc=0 na=0]
# [  148.938540] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  148.939871] FS-Cache: O-key=[8] '6d84070000000100'
# [  148.941817] FS-Cache: N-cookie c=00001982 [p=00000019 fl=2 nc=0 na=1]
# [  148.943283] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=0000000049c1311e
# [  148.945789] FS-Cache: N-key=[8] '6d84070000000100'
# [  149.001432] FS-Cache: Duplicate cookie detected
# [  149.003543] FS-Cache: O-cookie c=000019b3 [p=00000019 fl=216 nc=0 na=0]
# [  149.005588] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  149.007299] FS-Cache: O-key=[8] '6a02080000000300'
# [  149.008533] FS-Cache: N-cookie c=000019b4 [p=00000019 fl=2 nc=0 na=1]
# [  149.010315] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000997b79b4
# [  149.012235] FS-Cache: N-key=[8] '6a02080000000300'
# [  149.074500] FS-Cache: Duplicate cookie detected
# [  149.075907] FS-Cache: O-cookie c=000019eb [p=00000019 fl=216 nc=0 na=0]
# [  149.077391] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  149.078285] FS-Cache: O-key=[8] '58d4070000000300'
# [  149.079312] FS-Cache: N-cookie c=000019ec [p=00000019 fl=2 nc=0 na=1]
# [  149.081205] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000e5616df2
# [  149.083421] FS-Cache: N-key=[8] '58d4070000000300'
# [  149.340830] FS-Cache: Duplicate cookie detected
# [  149.342438] FS-Cache: O-cookie c=00001ae1 [p=00000019 fl=216 nc=0 na=0]
# [  149.344103] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  149.346616] FS-Cache: O-key=[8] '114c070000000100'
# [  149.347927] FS-Cache: N-cookie c=00001ae2 [p=00000019 fl=2 nc=0 na=1]
# [  149.349521] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000ff73fd45
# [  149.352018] FS-Cache: N-key=[8] '114c070000000100'
# [  149.388926] FS-Cache: Duplicate cookie detected
# [  149.390490] FS-Cache: O-cookie c=00001aff [p=00000019 fl=216 nc=0 na=0]
# [  149.392324] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  149.394858] FS-Cache: O-key=[8] 'ab71070000000100'
# [  149.395605] FS-Cache: N-cookie c=00001b00 [p=00000019 fl=2 nc=0 na=1]
# [  149.397641] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000e5616df2
# [  149.400422] FS-Cache: N-key=[8] 'ab71070000000100'
# [  149.442344] FS-Cache: Duplicate cookie detected
# [  149.443921] FS-Cache: O-cookie c=00001b23 [p=00000019 fl=216 nc=0 na=0]
# [  149.445342] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  149.446669] FS-Cache: O-key=[8] '20210a0000000100'
# [  149.448121] FS-Cache: N-cookie c=00001b24 [p=00000019 fl=2 nc=0 na=1]
# [  149.448933] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000e6c3e072
# [  149.450134] FS-Cache: N-key=[8] '20210a0000000100'
# [  149.473472] FS-Cache: Duplicate cookie detected
# [  149.474940] FS-Cache: O-cookie c=00001b35 [p=00000019 fl=216 nc=0 na=0]
# [  149.476024] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  149.477154] FS-Cache: O-key=[8] '84d3090000000200'
# [  149.478247] FS-Cache: N-cookie c=00001b36 [p=00000019 fl=2 nc=0 na=1]
# [  149.479499] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000bd92e090
# [  149.481047] FS-Cache: N-key=[8] '84d3090000000200'
# [  149.570263] FS-Cache: Duplicate cookie detected
# [  149.571969] FS-Cache: O-cookie c=00001b91 [p=00000019 fl=216 nc=0 na=0]
# [  149.573819] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  149.575326] FS-Cache: O-key=[8] 'd4be110000000200'
# [  149.576581] FS-Cache: N-cookie c=00001b92 [p=00000019 fl=2 nc=0 na=1]
# [  149.578295] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=000000007fb45d4a
# [  149.581209] FS-Cache: N-key=[8] 'd4be110000000200'
# [  149.599494] FS-Cache: Duplicate cookie detected
# [  149.601527] FS-Cache: O-cookie c=00001b9b [p=00000019 fl=216 nc=0 na=0]
# [  149.603436] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  149.605465] FS-Cache: O-key=[8] 'ab510a0000000200'
# [  149.606992] FS-Cache: N-cookie c=00001b9c [p=00000019 fl=2 nc=0 na=1]
# [  149.608628] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=0000000049c1311e
# [  149.610484] FS-Cache: N-key=[8] 'ab510a0000000200'
# [  149.655897] FS-Cache: Duplicate cookie detected
# [  149.657149] FS-Cache: O-cookie c=00001bb7 [p=00000019 fl=216 nc=0 na=0]
# [  149.658980] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  149.660929] FS-Cache: O-key=[8] '4176010000000400'
# [  149.661622] FS-Cache: N-cookie c=00001bb8 [p=00000019 fl=2 nc=0 na=1]
# [  149.662956] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=0000000049c1311e
# [  149.664758] FS-Cache: N-key=[8] '4176010000000400'
# [  149.691496] FS-Cache: Duplicate cookie detected
# [  149.693120] FS-Cache: O-cookie c=00001bcb [p=00000019 fl=216 nc=0 na=0]
# [  149.695360] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  149.697600] FS-Cache: O-key=[8] 'cf7e070000000100'
# [  149.698651] FS-Cache: N-cookie c=00001bcc [p=00000019 fl=2 nc=0 na=1]
# [  149.699876] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000896d5e3f
# [  149.702118] FS-Cache: N-key=[8] 'cf7e070000000100'
# [  149.707340] FS-Cache: Duplicate cookie detected
# [  149.708405] FS-Cache: O-cookie c=00001bcd [p=00000019 fl=216 nc=0 na=0]
# [  149.710353] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  149.712344] FS-Cache: O-key=[8] '2b46070000000100'
# [  149.714937] FS-Cache: N-cookie c=00001bce [p=00000019 fl=2 nc=0 na=1]
# [  149.716481] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=000000000a777d27
# [  149.719098] FS-Cache: N-key=[8] '2b46070000000100'
# [  149.736406] FS-Cache: Duplicate cookie detected
# [  149.738823] FS-Cache: O-cookie c=00001bd7 [p=00000019 fl=216 nc=0 na=0]
# [  149.740293] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  149.742127] FS-Cache: O-key=[8] '1b7e0a0000000100'
# [  149.744125] FS-Cache: N-cookie c=00001bd8 [p=00000019 fl=2 nc=0 na=1]
# [  149.746471] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000f13ff036
# [  149.747812] FS-Cache: N-key=[8] '1b7e0a0000000100'
# [  149.840992] FS-Cache: Duplicate cookie detected
# [  149.843137] FS-Cache: O-cookie c=00001c21 [p=00000019 fl=216 nc=0 na=0]
# [  149.845387] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  149.847758] FS-Cache: O-key=[8] '9c1e0a0000000100'
# [  149.849200] FS-Cache: N-cookie c=00001c22 [p=00000019 fl=2 nc=0 na=1]
# [  149.850361] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=0000000047cd72d5
# [  149.853059] FS-Cache: N-key=[8] '9c1e0a0000000100'
# [  149.942898] FS-Cache: Duplicate cookie detected
# [  149.944574] FS-Cache: O-cookie c=00001c7d [p=00000019 fl=216 nc=0 na=0]
# [  149.946624] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  149.947776] FS-Cache: O-key=[8] 'af1f070000000100'
# [  149.948754] FS-Cache: N-cookie c=00001c7e [p=00000019 fl=2 nc=0 na=1]
# [  149.950351] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000daa83b2d
# [  149.952440] FS-Cache: N-key=[8] 'af1f070000000100'
# [  150.072331] FS-Cache: Duplicate cookie detected
# [  150.073618] FS-Cache: O-cookie c=00001cd9 [p=00000019 fl=216 nc=0 na=0]
# [  150.074258] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  150.074936] FS-Cache: O-key=[8] '7253090000000400'
# [  150.075360] FS-Cache: N-cookie c=00001cda [p=00000019 fl=2 nc=0 na=1]
# [  150.075847] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=0000000010f365a1
# [  150.076528] FS-Cache: N-key=[8] '7253090000000400'
# [  150.317994] FS-Cache: Duplicate cookie detected
# [  150.318649] FS-Cache: O-cookie c=00001e03 [p=00000019 fl=216 nc=0 na=0]
# [  150.319192] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  150.319617] FS-Cache: O-key=[8] '81a5070000000500'
# [  150.319927] FS-Cache: N-cookie c=00001e04 [p=00000019 fl=2 nc=0 na=1]
# [  150.320493] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000a38d5ae1
# [  150.320969] FS-Cache: N-key=[8] '81a5070000000500'
# [  150.324134] FS-Cache: Duplicate cookie detected
# [  150.324789] FS-Cache: O-cookie c=00001e05 [p=00000019 fl=216 nc=0 na=0]
# [  150.325207] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  150.325676] FS-Cache: O-key=[8] '8ca5070000000500'
# [  150.325967] FS-Cache: N-cookie c=00001e06 [p=00000019 fl=2 nc=0 na=1]
# [  150.326251] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000968ec2fc
# [  150.326596] FS-Cache: N-key=[8] '8ca5070000000500'
# [  150.386395] FS-Cache: Duplicate cookie detected
# [  150.387128] FS-Cache: O-cookie c=00001e35 [p=00000019 fl=216 nc=0 na=0]
# [  150.388290] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  150.389522] FS-Cache: O-key=[8] '0fb0110000000200'
# [  150.390099] FS-Cache: N-cookie c=00001e36 [p=00000019 fl=2 nc=0 na=1]
# [  150.390838] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=0000000013e23b5e
# [  150.391772] FS-Cache: N-key=[8] '0fb0110000000200'
# [  150.399887] FS-Cache: Duplicate cookie detected
# [  150.400669] FS-Cache: O-cookie c=00001e3b [p=00000019 fl=216 nc=0 na=0]
# [  150.401569] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  150.402219] FS-Cache: O-key=[8] 'dd35010000000600'
# [  150.402716] FS-Cache: N-cookie c=00001e3c [p=00000019 fl=2 nc=0 na=1]
# [  150.403932] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=000000001e131cba
# [  150.404745] FS-Cache: N-key=[8] 'dd35010000000600'
# [  150.578319] FS-Cache: Duplicate cookie detected
# [  150.578776] FS-Cache: O-cookie c=00001f09 [p=00000019 fl=216 nc=0 na=0]
# [  150.579045] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  150.579270] FS-Cache: O-key=[8] '20be110000000200'
# [  150.579858] FS-Cache: N-cookie c=00001f0a [p=00000019 fl=2 nc=0 na=1]
# [  150.580123] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=000000009be3ec7d
# [  150.580375] FS-Cache: N-key=[8] '20be110000000200'
# [  150.599531] FS-Cache: Duplicate cookie detected
# [  150.599946] FS-Cache: O-cookie c=00001f43 [p=00000019 fl=216 nc=0 na=0]
# [  150.600508] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  150.602665] FS-Cache: O-key=[8] '6e68000000000700'
# [  150.603064] FS-Cache: N-cookie c=00001f44 [p=00000019 fl=2 nc=0 na=1]
# [  150.603402] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000be22ff23
# [  150.603742] FS-Cache: N-key=[8] '6e68000000000700'
# [  150.699488] FS-Cache: Duplicate cookie detected
# [  150.700871] FS-Cache: O-cookie c=00001fa9 [p=00000019 fl=216 nc=0 na=0]
# [  150.701653] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  150.702180] FS-Cache: O-key=[8] '204e0a0000000100'
# [  150.702570] FS-Cache: N-cookie c=00001faa [p=00000019 fl=2 nc=0 na=1]
# [  150.702980] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=000000005d0014b0
# [  150.703495] FS-Cache: N-key=[8] '204e0a0000000100'
# [  150.712163] FS-Cache: Duplicate cookie detected
# [  150.713244] FS-Cache: O-cookie c=00001fb7 [p=00000019 fl=216 nc=0 na=0]
# [  150.714097] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  150.714862] FS-Cache: O-key=[8] 'feae110000000200'
# [  150.715151] FS-Cache: N-cookie c=00001fb8 [p=00000019 fl=2 nc=0 na=1]
# [  150.715628] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=000000009fa3dcbe
# [  150.716125] FS-Cache: N-key=[8] 'feae110000000200'
# [  150.812886] FS-Cache: Duplicate cookie detected
# [  150.813548] FS-Cache: O-cookie c=00002067 [p=00000019 fl=216 nc=0 na=0]
# [  150.814557] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  150.815100] FS-Cache: O-key=[8] '2272070000000100'
# [  150.815335] FS-Cache: N-cookie c=00002068 [p=00000019 fl=2 nc=0 na=1]
# [  150.815974] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000e2fc5507
# [  150.817194] FS-Cache: N-key=[8] '2272070000000100'
# [  150.840750] FS-Cache: Duplicate cookie detected
# [  150.841331] FS-Cache: O-cookie c=0000209b [p=00000019 fl=216 nc=0 na=0]
# [  150.841851] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  150.843129] FS-Cache: O-key=[8] '83330a0000000200'
# [  150.843516] FS-Cache: N-cookie c=0000209c [p=00000019 fl=2 nc=0 na=1]
# [  150.843777] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=000000000abceb8c
# [  150.844276] FS-Cache: N-key=[8] '83330a0000000200'
# [  150.857693] FS-Cache: Duplicate cookie detected
# [  150.858028] FS-Cache: O-cookie c=000020bb [p=00000019 fl=216 nc=0 na=0]
# [  150.858261] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  150.858579] FS-Cache: O-key=[8] '24dc070000000600'
# [  150.858967] FS-Cache: N-cookie c=000020bc [p=00000019 fl=2 nc=0 na=1]
# [  150.859430] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000adfd0631
# [  150.859984] FS-Cache: N-key=[8] '24dc070000000600'
# [  150.861925] FS-Cache: Duplicate cookie detected
# [  150.862241] FS-Cache: O-cookie c=000020bf [p=00000019 fl=216 nc=0 na=0]
# [  150.862461] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  150.862813] FS-Cache: O-key=[8] 'bb4e080000000900'
# [  150.863038] FS-Cache: N-cookie c=000020c0 [p=00000019 fl=2 nc=0 na=1]
# [  150.863264] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000a51b27e1
# [  150.863637] FS-Cache: N-key=[8] 'bb4e080000000900'
# [  150.891334] FS-Cache: Duplicate cookie detected
# [  150.891798] FS-Cache: O-cookie c=0000210b [p=00000019 fl=216 nc=0 na=0]
# [  150.892067] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  150.892392] FS-Cache: O-key=[8] '0adb060000000100'
# [  150.892949] FS-Cache: N-cookie c=0000210c [p=00000019 fl=2 nc=0 na=1]
# [  150.893304] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000e71043a1
# [  150.893620] FS-Cache: N-key=[8] '0adb060000000100'
# [  151.024484] FS-Cache: Duplicate cookie detected
# [  151.024973] FS-Cache: O-cookie c=00002247 [p=00000019 fl=216 nc=0 na=0]
# [  151.025213] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  151.025480] FS-Cache: O-key=[8] '8e48070000000100'
# [  151.025738] FS-Cache: N-cookie c=00002248 [p=00000019 fl=2 nc=0 na=1]
# [  151.026091] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000b6995519
# [  151.026336] FS-Cache: N-key=[8] '8e48070000000100'
# [  151.162507] FS-Cache: Duplicate cookie detected
# [  151.163056] FS-Cache: O-cookie c=000023b1 [p=00000019 fl=216 nc=0 na=0]
# [  151.163470] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [  151.164258] FS-Cache: O-key=[8] 'c9200a0000000100'
# [  151.164657] FS-Cache: N-cookie c=000023b2 [p=00000019 fl=2 nc=0 na=1]
# [  151.164989] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000ad11d69e
# [  151.165220] FS-Cache: N-key=[8] 'c9200a0000000100'
# [  151.167975] FS-Cache: Duplicate cookie detected
# ...
# [ 3593.340799] FS-Cache: Duplicate cookie detected
# [ 3593.341197] FS-Cache: O-cookie c=00004d83 [p=00000019 fl=216 nc=0 na=0]
# [ 3593.341546] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [ 3593.341961] FS-Cache: O-key=[8] '003f0a0000000100'
# [ 3593.342329] FS-Cache: N-cookie c=00004d84 [p=00000019 fl=2 nc=0 na=1]
# [ 3593.342667] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000e9efca2d
# [ 3593.343109] FS-Cache: N-key=[8] '003f0a0000000100'
# [ 3593.362858] FS-Cache: Duplicate cookie detected
# [ 3593.363382] FS-Cache: O-cookie c=00004db7 [p=00000019 fl=216 nc=0 na=0]
# [ 3593.363732] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [ 3593.364112] FS-Cache: O-key=[8] '49be070000000500'
# [ 3593.364381] FS-Cache: N-cookie c=00004db8 [p=00000019 fl=2 nc=0 na=1]
# [ 3593.364825] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000cc455a92
# [ 3593.365171] FS-Cache: N-key=[8] '49be070000000500'
# [ 3593.374579] FS-Cache: Duplicate cookie detected
# [ 3593.375004] FS-Cache: O-cookie c=00004dd1 [p=00000019 fl=216 nc=0 na=0]
# [ 3593.375231] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [ 3593.375514] FS-Cache: O-key=[8] '222b0a0000000100'
# [ 3593.375725] FS-Cache: N-cookie c=00004dd2 [p=00000019 fl=2 nc=0 na=1]
# [ 3593.375956] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=000000000e4d52d5
# [ 3593.376257] FS-Cache: N-key=[8] '222b0a0000000100'
# [ 3593.390800] FS-Cache: Duplicate cookie detected
# [ 3593.391340] FS-Cache: O-cookie c=00004df5 [p=00000019 fl=216 nc=0 na=0]
# [ 3593.391821] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [ 3593.392280] FS-Cache: O-key=[8] 'd44a0a0000000100'
# [ 3593.392646] FS-Cache: N-cookie c=00004df6 [p=00000019 fl=2 nc=0 na=1]
# [ 3593.393100] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000ec2758f5
# [ 3593.393643] FS-Cache: N-key=[8] 'd44a0a0000000100'
# [ 3593.396662] FS-Cache: Duplicate cookie detected
# [ 3593.397029] FS-Cache: O-cookie c=00004dfd [p=00000019 fl=216 nc=0 na=0]
# [ 3593.397407] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [ 3593.397851] FS-Cache: O-key=[8] 'e1450a0000000100'
# [ 3593.398205] FS-Cache: N-cookie c=00004dfe [p=00000019 fl=2 nc=0 na=1]
# [ 3593.398626] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000da247258
# [ 3593.399011] FS-Cache: N-key=[8] 'e1450a0000000100'
# [ 3593.400008] FS-Cache: Duplicate cookie detected
# [ 3593.400477] FS-Cache: O-cookie c=00004dff [p=00000019 fl=216 nc=0 na=0]
# [ 3593.400934] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [ 3593.401392] FS-Cache: O-key=[8] '62e1090000000200'
# [ 3593.401758] FS-Cache: N-cookie c=00004e00 [p=00000019 fl=2 nc=0 na=1]
# [ 3593.402212] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000bda698d4
# [ 3593.402724] FS-Cache: N-key=[8] '62e1090000000200'
# [ 3593.408175] FS-Cache: Duplicate cookie detected
# [ 3593.408504] FS-Cache: O-cookie c=00004e0d [p=00000019 fl=216 nc=0 na=0]
# [ 3593.408846] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [ 3593.409164] FS-Cache: O-key=[8] 'e74d0a0000000100'
# [ 3593.409426] FS-Cache: N-cookie c=00004e0e [p=00000019 fl=2 nc=0 na=1]
# [ 3593.409973] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=000000002ace2392
# [ 3593.410529] FS-Cache: N-key=[8] 'e74d0a0000000100'
# [ 3593.415420] FS-Cache: Duplicate cookie detected
# [ 3593.415980] FS-Cache: O-cookie c=00004e1b [p=00000019 fl=216 nc=0 na=0]
# [ 3593.416504] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [ 3593.416956] FS-Cache: O-key=[8] 'fc52090000000500'
# [ 3593.417321] FS-Cache: N-cookie c=00004e1c [p=00000019 fl=2 nc=0 na=1]
# [ 3593.417779] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000cc455a92
# [ 3593.418328] FS-Cache: N-key=[8] 'fc52090000000500'
# [ 3593.419484] FS-Cache: Duplicate cookie detected
# [ 3593.419930] FS-Cache: O-cookie c=00004e1d [p=00000019 fl=216 nc=0 na=0]
# [ 3593.420409] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [ 3593.420823] FS-Cache: O-key=[8] 'fe52090000000500'
# [ 3593.421133] FS-Cache: N-cookie c=00004e1e [p=00000019 fl=2 nc=0 na=1]
# [ 3593.421586] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=000000006fafeafd
# [ 3593.422120] FS-Cache: N-key=[8] 'fe52090000000500'
# [ 3593.424136] FS-Cache: Duplicate cookie detected
# [ 3593.424577] FS-Cache: O-cookie c=00004e21 [p=00000019 fl=216 nc=0 na=0]
# [ 3593.425035] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [ 3593.425512] FS-Cache: O-key=[8] '0053090000000500'
# [ 3593.425877] FS-Cache: N-cookie c=00004e22 [p=00000019 fl=2 nc=0 na=1]
# [ 3593.426328] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000dc91fb07
# [ 3593.426868] FS-Cache: N-key=[8] '0053090000000500'
# [ 3593.427965] FS-Cache: Duplicate cookie detected
# [ 3593.428387] FS-Cache: O-cookie c=00004e23 [p=00000019 fl=216 nc=0 na=0]
# [ 3593.428834] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [ 3593.429283] FS-Cache: O-key=[8] '09430a0000000100'
# [ 3593.429639] FS-Cache: N-cookie c=00004e24 [p=00000019 fl=2 nc=0 na=1]
# [ 3593.430086] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000b6995519
# [ 3593.430620] FS-Cache: N-key=[8] '09430a0000000100'
# [ 3593.432430] FS-Cache: Duplicate cookie detected
# [ 3593.432898] FS-Cache: O-cookie c=00004e27 [p=00000019 fl=216 nc=0 na=0]
# [ 3593.433398] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [ 3593.433625] FS-Cache: O-key=[8] '28aa110000000200'
# [ 3593.433986] FS-Cache: N-cookie c=00004e28 [p=00000019 fl=2 nc=0 na=1]
# [ 3593.434289] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=000000003dd4b2e0
# [ 3593.434882] FS-Cache: N-key=[8] '28aa110000000200'
# [ 3593.645667] FS-Cache: Duplicate cookie detected
# [ 3593.646519] FS-Cache: O-cookie c=00005051 [p=00000019 fl=216 nc=0 na=0]
# [ 3593.647260] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [ 3593.648285] FS-Cache: O-key=[8] '3d640a0000000200'
# [ 3593.648953] FS-Cache: N-cookie c=00005052 [p=00000019 fl=2 nc=0 na=1]
# [ 3593.649603] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=000000005a9296b8
# [ 3593.650857] FS-Cache: N-key=[8] '3d640a0000000200'
# [ 3593.653605] FS-Cache: Duplicate cookie detected
# [ 3593.654516] FS-Cache: O-cookie c=00005057 [p=00000019 fl=216 nc=0 na=0]
# [ 3593.654952] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [ 3593.655610] FS-Cache: O-key=[8] 'e5d8060000000100'
# [ 3593.655954] FS-Cache: N-cookie c=00005058 [p=00000019 fl=2 nc=0 na=1]
# [ 3593.656957] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=000000001100b352
# [ 3593.657569] FS-Cache: N-key=[8] 'e5d8060000000100'
# [ 3593.742111] FS-Cache: Duplicate cookie detected
# [ 3593.742539] FS-Cache: O-cookie c=00005115 [p=00000019 fl=216 nc=0 na=0]
# [ 3593.743367] FS-Cache: O-cookie d=0000000000000000{?} n=0000000000000000
# [ 3593.744587] FS-Cache: O-key=[8] 'b3b7090000000500'
# [ 3593.745497] FS-Cache: N-cookie c=00005116 [p=00000019 fl=2 nc=0 na=1]
# [ 3593.746740] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000eeb7b945
# [ 3593.748154] FS-Cache: N-key=[8] 'b3b7090000000500'
# [ 3692.225967] mini_init (239): drop_caches: 1
# [ 4096.937127] Adjusting tsc more than 11% (5480476 vs 6928093)
# [ 7172.759774] mini_init (239): drop_caches: 1
# [22624.579732] FS-Cache: Duplicate cookie detected
# [22624.582767] FS-Cache: O-cookie c=00000152 [p=00000019 fl=226 nc=0 na=1]
# [22624.584847] FS-Cache: O-cookie d=000000008b94470e{9p.inode} n=0000000011639222
# [22624.585814] FS-Cache: O-key=[8] 'e2a6000000003d00'
# [22624.586605] FS-Cache: N-cookie c=00005252 [p=00000019 fl=2 nc=0 na=1]
# [22624.587385] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=000000009a00250d
# [22624.588075] FS-Cache: N-key=[8] 'e2a6000000003d00'
# [22624.595251] FS-Cache: Duplicate cookie detected
# [22624.596794] FS-Cache: O-cookie c=00000152 [p=00000019 fl=226 nc=0 na=1]
# [22624.598329] FS-Cache: O-cookie d=000000008b94470e{9p.inode} n=0000000011639222
# [22624.600062] FS-Cache: O-key=[8] 'e2a6000000003d00'
# [22624.600421] FS-Cache: N-cookie c=00005253 [p=00000019 fl=2 nc=0 na=1]
# [22624.601470] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000daa83b2d
# [22624.601952] FS-Cache: N-key=[8] 'e2a6000000003d00'
# [22624.681283] FS-Cache: Duplicate cookie detected
# [22624.681705] FS-Cache: O-cookie c=00000152 [p=00000019 fl=226 nc=0 na=1]
# [22624.683044] FS-Cache: O-cookie d=000000008b94470e{9p.inode} n=0000000011639222
# [22624.683514] FS-Cache: O-key=[8] 'e2a6000000003d00'
# [22624.683718] FS-Cache: N-cookie c=0000525c [p=00000019 fl=2 nc=0 na=1]
# [22624.683901] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=000000006472c357
# [22624.684178] FS-Cache: N-key=[8] 'e2a6000000003d00'
# [22624.687141] FS-Cache: Duplicate cookie detected
# [22624.687510] FS-Cache: O-cookie c=00000152 [p=00000019 fl=226 nc=0 na=1]
# [22624.687805] FS-Cache: O-cookie d=000000008b94470e{9p.inode} n=0000000011639222
# [22624.688129] FS-Cache: O-key=[8] 'e2a6000000003d00'
# [22624.688399] FS-Cache: N-cookie c=0000525d [p=00000019 fl=2 nc=0 na=1]
# [22624.688674] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000846c9051
# [22624.689028] FS-Cache: N-key=[8] 'e2a6000000003d00'
# [22624.694648] FS-Cache: Duplicate cookie detected
# [22624.695005] FS-Cache: O-cookie c=00000152 [p=00000019 fl=226 nc=0 na=1]
# [22624.695386] FS-Cache: O-cookie d=000000008b94470e{9p.inode} n=0000000011639222
# [22624.696720] FS-Cache: O-key=[8] 'e2a6000000003d00'
# [22624.697547] FS-Cache: N-cookie c=0000525e [p=00000019 fl=2 nc=0 na=1]
# [22624.698204] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000e73f76c7
# [22624.699984] FS-Cache: N-key=[8] 'e2a6000000003d00'
# [22624.703453] FS-Cache: Duplicate cookie detected
# [22624.703981] FS-Cache: O-cookie c=00000152 [p=00000019 fl=226 nc=0 na=1]
# [22624.705160] FS-Cache: O-cookie d=000000008b94470e{9p.inode} n=0000000011639222
# [22624.706880] FS-Cache: O-key=[8] 'e2a6000000003d00'
# [22624.707252] FS-Cache: N-cookie c=0000525f [p=00000019 fl=2 nc=0 na=1]
# [22624.707699] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=0000000010f365a1
# [22624.708047] FS-Cache: N-key=[8] 'e2a6000000003d00'
# [22626.190762] FS-Cache: Duplicate cookie detected
# [22626.192297] FS-Cache: O-cookie c=00000152 [p=00000019 fl=226 nc=0 na=1]
# [22626.192760] FS-Cache: O-cookie d=000000008b94470e{9p.inode} n=0000000011639222
# [22626.193631] FS-Cache: O-key=[8] 'e2a6000000003d00'
# [22626.193965] FS-Cache: N-cookie c=000052d5 [p=00000019 fl=2 nc=0 na=1]
# [22626.194658] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=0000000078f444d4
# [22626.195247] FS-Cache: N-key=[8] 'e2a6000000003d00'
# [22626.198284] FS-Cache: Duplicate cookie detected
# [22626.198925] FS-Cache: O-cookie c=00000152 [p=00000019 fl=226 nc=0 na=1]
# [22626.199445] FS-Cache: O-cookie d=000000008b94470e{9p.inode} n=0000000011639222
# [22626.200178] FS-Cache: O-key=[8] 'e2a6000000003d00'
# [22626.200449] FS-Cache: N-cookie c=000052d6 [p=00000019 fl=2 nc=0 na=1]
# [22626.200997] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=000000002c7eba3c
# [22626.201594] FS-Cache: N-key=[8] 'e2a6000000003d00'
# [22626.204369] FS-Cache: Duplicate cookie detected
# [22626.204999] FS-Cache: O-cookie c=00000152 [p=00000019 fl=226 nc=0 na=1]
# [22626.205597] FS-Cache: O-cookie d=000000008b94470e{9p.inode} n=0000000011639222
# [22626.206207] FS-Cache: O-key=[8] 'e2a6000000003d00'
# [22626.206643] FS-Cache: N-cookie c=000052d7 [p=00000019 fl=2 nc=0 na=1]
# [22626.207047] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=000000008596ec38
# [22626.207357] FS-Cache: N-key=[8] 'e2a6000000003d00'
# [22626.210215] FS-Cache: Duplicate cookie detected
# [22626.210716] FS-Cache: O-cookie c=00000152 [p=00000019 fl=226 nc=0 na=1]
# [22626.211030] FS-Cache: O-cookie d=000000008b94470e{9p.inode} n=0000000011639222
# [22626.211564] FS-Cache: O-key=[8] 'e2a6000000003d00'
# [22626.212060] FS-Cache: N-cookie c=000052d8 [p=00000019 fl=2 nc=0 na=1]
# [22626.213074] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=0000000036aebe1c
# [22626.213972] FS-Cache: N-key=[8] 'e2a6000000003d00'
# [22626.810046] FS-Cache: Duplicate cookie detected
# [22626.811696] FS-Cache: O-cookie c=00000152 [p=00000019 fl=226 nc=0 na=1]
# [22626.812952] FS-Cache: O-cookie d=000000008b94470e{9p.inode} n=0000000011639222
# [22626.814435] FS-Cache: O-key=[8] 'e2a6000000003d00'
# [22626.815662] FS-Cache: N-cookie c=00005316 [p=00000019 fl=2 nc=0 na=1]
# [22626.816444] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000f1b8d9cd
# [22626.816979] FS-Cache: N-key=[8] 'e2a6000000003d00'
# [22626.818423] FS-Cache: Duplicate cookie detected
# [22626.818812] FS-Cache: O-cookie c=00000152 [p=00000019 fl=226 nc=0 na=1]
# [22626.819193] FS-Cache: O-cookie d=000000008b94470e{9p.inode} n=0000000011639222
# [22626.819506] FS-Cache: O-key=[8] 'e2a6000000003d00'
# [22626.819683] FS-Cache: N-cookie c=00005317 [p=00000019 fl=2 nc=0 na=1]
# [22626.820125] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000e9efca2d
# [22626.820396] FS-Cache: N-key=[8] 'e2a6000000003d00'
# [22626.830835] FS-Cache: Duplicate cookie detected
# [22626.831328] FS-Cache: O-cookie c=00000152 [p=00000019 fl=226 nc=0 na=1]
# [22626.831618] FS-Cache: O-cookie d=000000008b94470e{9p.inode} n=0000000011639222
# [22626.832630] FS-Cache: O-key=[8] 'e2a6000000003d00'
# [22626.832866] FS-Cache: N-cookie c=00005319 [p=00000019 fl=2 nc=0 na=1]
# [22626.833284] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000182489b8
# [22626.833858] FS-Cache: N-key=[8] 'e2a6000000003d00'
# [22626.837550] FS-Cache: Duplicate cookie detected
# [22626.837963] FS-Cache: O-cookie c=00000152 [p=00000019 fl=226 nc=0 na=1]
# [22626.838521] FS-Cache: O-cookie d=000000008b94470e{9p.inode} n=0000000011639222
# [22626.838854] FS-Cache: O-key=[8] 'e2a6000000003d00'
# [22626.839286] FS-Cache: N-cookie c=0000531b [p=00000019 fl=2 nc=0 na=1]
# [22626.839628] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000effd5920
# [22626.840150] FS-Cache: N-key=[8] 'e2a6000000003d00'
# [22774.012131] mini_init (239): drop_caches: 1
# [23663.911301] systemd-journald[54]: Time jumped backwards, rotating.
# [25440.864975] systemd-journald[54]: Time jumped backwards, rotating.
# [26093.327974] systemd-journald[54]: Time jumped backwards, rotating.
# [30854.248118] systemd-journald[54]: Time jumped backwards, rotating.
# [31264.699373] mini_init (239): drop_caches: 1
# [31324.648321] mini_init (239): drop_caches: 1
# [42847.037244] mini_init (239): drop_caches: 1
# [45286.644411] FS-Cache: Duplicate cookie detected
# [45286.647747] FS-Cache: O-cookie c=000068a7 [p=00000019 fl=226 nc=0 na=1]
# [45286.648885] FS-Cache: O-cookie d=000000008b94470e{9p.inode} n=00000000b590f65a
# [45286.651025] FS-Cache: O-key=[8] '8a5e010000001600'
# [45286.651834] FS-Cache: N-cookie c=000068a8 [p=00000019 fl=2 nc=0 na=1]
# [45286.652470] FS-Cache: N-cookie d=000000008b94470e{9p.inode} n=00000000fc3154c9
# [45286.653653] FS-Cache: N-key=[8] '8a5e010000001600'
# [45307.218051] mini_init (239): drop_caches: 1
# [49358.165550] mini_init (239): drop_caches: 1
# [49483.756225] systemd-journald[54]: Time jumped backwards, rotating.
# [49992.689484] systemd-journald[54]: Time jumped backwards, rotating.
# [50373.878492] systemd-journald[54]: Time jumped backwards, rotating.
# [51518.582978] mini_init (239): drop_caches: 1
# [51657.242803] systemd-journald[54]: Time jumped backwards, rotating.
# [51657.675101] hv_utils: TimeSync IC version 4.0
# [53564.294128] systemd-journald[54]: Time jumped backwards, rotating.
# [53965.683592] systemd-journald[54]: Time jumped backwards, rotating.
# [56050.849830] systemd-journald[54]: Time jumped backwards, rotating.
# [58105.791207] systemd-journald[54]: Time jumped backwards, rotating.
# [61394.748751] systemd-journald[54]: Time jumped backwards, rotating.
# [61395.164604] hv_utils: TimeSync IC version 4.0
# [61434.371059] TCP: eth0: Driver has suspect GRO implementation, TCP performance may be compromised.
# [61500.028405] mini_init (239): drop_caches: 1
# [62780.205591] systemd-journald[54]: Time jumped backwards, rotating.
# [64865.158422] systemd-journald[54]: Time jumped backwards, rotating.
# [65272.613070] systemd-journald[54]: Time jumped backwards, rotating.
# [65680.758949] systemd-journald[54]: Time jumped backwards, rotating.

# %% [markdown]
# ## Demo 19: Working with System Logs and Text Manipulation in Linux
#
# ### 18.1. `dmesg > dmesg.txt`
#
# #### Input:
# ```bash
# dmesg > dmesg.txt
# ```
#
# #### Output:
# This command writes the kernel's log messages (which can include hardware details, boot-up sequences, etc.) into a text file called `dmesg.txt`.
#
# #### Explanation:
# - `dmesg` is used to display system messages, especially messages related to the kernel, like hardware and boot-up diagnostics.
# - The `>` symbol redirects the output of `dmesg` into a new file called `dmesg.txt`.
#
# ---
#
# ### 18.2. `vi dmesg.txt`
#
# #### Input:
# ```bash
# vi dmesg.txt
# ```
#
# #### Output:
# Opens the `dmesg.txt` file in the `vi` text editor. You can now view or edit the contents of the file.
#
# #### Explanation:
# - `vi` is a command-line text editor in Linux. It opens files for reading or editing.
# - You can navigate inside the file using the arrow keys.
#
# ---
#
# ### 18.3. Delete 100 lines using `100dd`
#
# #### Input:
# In `vi`, after opening `dmesg.txt`, type the following command:
# ```bash
# 100dd
# ```
#
# #### Output:
# This command deletes 100 lines from the current cursor position.
#
# #### Explanation:
# - In `vi`, `dd` deletes a single line, but by prefixing it with a number (in this case, `100`), you instruct `vi` to delete 100 lines.
#
# ---
#
# ### 18.4. Run a Command Multiple Times by Suffixing a Number
#
# #### Input:
# ```bash
# 5dd
# ```
#
# #### Output:
# This command deletes 5 lines from the current cursor position.
#
# #### Explanation:
# - In `vi`, you can run any command multiple times by adding a number before it. In this case, `5dd` deletes 5 lines.
# - Similarly, you could use this logic to repeat other commands like moving the cursor (`10j` to move down 10 lines), or inserting text (`3i` to enter insert mode 3 times).
#
# ---
#
# ### 18.5. Display the Number of Lines in the File
#
# #### Input:
# After editing the file in `vi`, type:
# ```bash
# :g/^/p
# ```
#
# #### Output:
# This will print the total number of lines in the file.
#
# #### Explanation:
# - In `vi`, the `:g/^/p` command will print each line that matches the beginning of a line (`^` means the start of the line), essentially displaying the entire content.
# - You can count how many lines it prints to see the number of lines in your file.
#
# ---
#
# ### 18.6. Replace All Occurrences of 'PCI' with 'hello'
#
# #### Input:
# In `vi`, type:
# ```bash
# :%s/PCI/hello/g
# ```
#
# #### Output:
# This command replaces all occurrences of the word "PCI" with "hello" throughout the entire file.
#
# #### Explanation:
# - `:%s` is the command to substitute text in the entire file (`%` means all lines).
# - `/PCI/hello/` specifies that you want to replace the word "PCI" with "hello".
# - The `g` at the end ensures the replacement happens globally across the file (everywhere, not just the first instance on each line).
#
# ---
#
# ### 18.7. Replace Patterns Matching a Specific Format
#
# #### Input:
# In `vi`, type:
# ```bash
# :%s/....:../NULL/g
# ```
#
# #### Output:
# This command replaces any string with the format `....:..` (four characters followed by a colon and then two more characters) with the word "NULL" throughout the entire file.
#
# #### Explanation:
# - `....:..` is a regular expression that matches any four characters, followed by a colon, and then two characters.
# - This is useful if you're looking to replace things like time stamps (e.g., `12:34:56`), memory addresses, or hardware IDs.
# - The `g` ensures that it does this replacement globally across the entire file.
#
# ---

# %% [markdown]
# ## Demo 20: Searching for Patterns with Regular Expressions
#
# ### Searching for a Specific Pattern
#
# We want to search for any sequence in the file that matches the pattern `....:..`. This represents four characters followed by a colon and then two more characters, such as `abcd:12`.
#
# #### Command:
# ```
# ```bash
# /....:..
# ```
#
# #### Explanation:
# - `....:..` is a regular expression that searches for any sequence of four characters (`....`), followed by a colon (`:`), and two characters (`..`).
# - This pattern can be used to find things like timestamps (e.g., `12:34`), memory addresses, or formatted data in your text.
#
# After typing the command, `vi` will highlight the first match it finds. You can press `n` to jump to the next occurrence.
#
# #### Example:
# In a file with contents like:
# ```
# 2023:10 log entry
# abcd:12 hardware issue
# efgh:45 something else
# ```
# The search `/....:..` will highlight entries like `2023:10`, `abcd:12`, and `efgh:45`.
#
# ---
#
# ## Demo 21: Remove Text Between Square Brackets
#
#
# Now, we’ll remove all text inside square brackets `[]`, including the brackets themselves, using a substitution command.
#
# #### Command:
# ```
# ```bash
# :%s/\[.*\]//g
# ```
#
# #### Explanation:
# - `\[.*\]` is a regular expression where:
#   - `\[ \]` represents literal square brackets (we escape them with `\` because brackets have a special meaning in regex).
#   - `.*` matches any characters inside the brackets.
# - This command searches the entire file (`%` for all lines) and replaces everything inside square brackets, including the brackets, with nothing (`//`), effectively deleting it.
# - The `g` at the end ensures the substitution happens globally, across all instances on each line.
#
# #### Example:
# In a file with contents like:
# ```
# Error [404] on line 1
# Warning [301] on line 2
# Debug [info] on line 3
# ```
# Running the command `:%s/\[.*\]//g` will produce:
# ```
# Error  on line 1
# Warning  on line 2
# Debug  on line 3
# ```
#
# Here, everything inside square brackets and the brackets themselves are removed.
#
# ---
# ## Demo 22: Replace 'LINE' with 'line'
#
# In this step, we'll replace all occurrences of 'LINE' (uppercase) with 'line' (lowercase). This replacement is case-sensitive, meaning it will only replace 'LINE' and leave instances of 'line' unchanged.
#
# #### Command:
# ```
# ```bash
# :%s/LINE/line/g
# ```
#
# #### Explanation:
# - `LINE` refers to the specific word in uppercase that we want to replace.
# - `line` is the lowercase version we want to substitute it with.
# - The `g` ensures the replacement happens globally across all lines.
#
# #### Example:
# In a file with contents like:
# ```
# LINE 1: Start here
# This is a line of text.
# LINE 2: Continue here
# ```
# Running the command `:%s/LINE/line/g` will produce:
# ```
# line 1: Start here
# This is a line of text.
# line 2: Continue here
# ```
#
# Notice that only the uppercase 'LINE' is replaced, and the lowercase 'line' remains unchanged.
#
# ---
#
# ## Demo 23: Replacing 'line' with an Email Address
#
#
# In this demo, we'll replace all instances of the word 'line' with the email address `line@iitm.ac.in`. This is useful when you want to replace placeholders with real data.
#
# #### Command:
# ```
# ```bash
# :%s/line/line@iitm.ac.in/g
# ```
#
# #### Explanation:
# - `line` refers to the word we want to replace.
# - `line@iitm.ac.in` is the replacement text, in this case, an email address.
# - The `g` at the end ensures all instances of 'line' are replaced globally.
#
# #### Example:
# In a file with contents like:
# ```
# This is a line of text.
# Another line appears here.
# ```
# Running the command `:%s/line/line@iitm.ac.in/g` will produce:
# ```
# This is a line@iitm.ac.in of text.
# Another line@iitm.ac.in appears here.
# ```
#
# Every occurrence of the word 'line' is replaced with `line@iitm.ac.in`.
# ```
#
# ---

# %% [markdown]
# ## Demo 24. Opening Emacs in No Window Mode (Emacs Terminal Mode)
#
# ### Command:
# ```bash
# emacs -nw filename.c
# ```
#
# ### Details:
# - The `-nw` option in Emacs stands for **no window**, which means Emacs will run directly in the terminal, without opening a graphical interface. This is useful if you're working on a system without a graphical desktop environment or over SSH.
# - Replace `filename.c` with the name of the file you want to edit. In this case, we assume you are editing a C file (`filename.c`).
#
# ### Example:
# ```bash
# emacs -nw hello_world.c
# ```
#
# #### Sample Output:
# This command opens `hello_world.c` in Emacs within the terminal, where you can immediately begin editing the file.
#
# ---
#
# ## Demo 25. Moving Around in Emacs and Basic Editing
#
# ### Movement and Typing:
# In Emacs, there is no "command mode" like in `vi`. You are always in a mode where you can directly edit text. You can move the cursor around and start typing wherever you like. Deleting text is just as simple as using the **Backspace** key.
#
# ### Commands for Navigation and Editing:
#
# | Command    | Action |
# |------------|--------|
# | `C-d`      | Delete character under the cursor |
# | `C-b`      | Move cursor left by one character |
# | `M-b`      | Move cursor to the beginning of the previous word |
# | `M-f`      | Move cursor to the end of the next word |
# | `M-a`      | Move cursor to the beginning of the current sentence |
# | `M-e`      | Move cursor to the end of the current sentence |
# | `C-v`      | Scroll down one screen (page down) |
# | `M-v`      | Scroll up one screen (page up) |
# | `C-a`      | Move cursor to the beginning of the current line |
# | `C-e`      | Move cursor to the end of the current line |
#
# ### Explanation of Keys:
# - `C-` means holding down **Control** (Ctrl) while pressing the key.
# - `M-` means holding down **Meta** (usually **Alt**) while pressing the key.
#
# ### Example 25.1: Move to Beginning and End of a Line
# - Press `C-a` to move the cursor to the start of the current line.
# - Press `C-e` to move the cursor to the end of the current line.
#
# ### Example 25.2: Moving by Words
# - Press `M-b` to move to the beginning of the previous word.
# - Press `M-f` to move to the end of the next word.
#
# ### Example 25.3: Scrolling the Page
# - Press `C-v` to scroll one page down.
# - Press `M-v` to scroll one page up.
#
# ### Example 25.4: Deleting a Character
# - Press `C-d` to delete the character under the cursor.
#
# #### Sample Interaction:
# - If you're editing a C file with the following line:
#
# ```c
# int main() {
# ```
#
# - Press `M-b` to move the cursor to the beginning of the word `main()`.
# - Press `C-d` to delete the character under the cursor (`m` in this case).
#
# ---
#
# ## Demo 26. Saving and Exiting in Emacs
#
# ### Commands to Save and Exit:
#
# | Command        | Action                              |
# |----------------|-------------------------------------|
# | `C-x C-s`      | Save the current buffer to a file   |
# | `C-x C-c`      | Save and exit Emacs                |
# | `C-z`          | Suspend Emacs (minimizes it)       |
#
# ### Explanation:
# - **Saving**: In Emacs, you save the file using the command `C-x C-s` (Control + x followed by Control + s). This writes the current changes in the buffer to the file on disk.
# - **Exiting**: To exit Emacs, you can use `C-x C-c` (Control + x followed by Control + c). This will prompt you to save any unsaved changes before closing.
# - **Suspend**: If you don't want to close Emacs entirely but want to minimize it or suspend it in the terminal, you can use `C-z`. This will suspend Emacs, and you can resume it later.
#
# ### Example:
#
# 1. **Save Changes:**
#    - You've made some changes to `hello_world.c`. Press `C-x C-s` to save those changes.
#
# 2. **Exit Emacs:**
#    - To close Emacs, press `C-x C-c`. Emacs will close, and you will return to the terminal.
#
# 3. **Suspend Emacs:**
#    - If you want to minimize Emacs without closing it, press `C-z`. This will suspend Emacs, and you can bring it back by typing `fg` in the terminal.
#
# #### Sample Output:
# - When you press `C-x C-s`, Emacs will display a message at the bottom indicating the file was saved successfully:
#
# ```
# Wrote /path/to/your/file/hello_world.c
# ```
#
# - After pressing `C-x C-c`, Emacs will close, and you will be back in the terminal.
#
# ---
#
# Remember, practice is key to mastering Emacs!
